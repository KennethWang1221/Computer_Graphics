# %%
import torch
import numpy as np
import cv2
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.patches import Circle
from skimage import transform
from skimage.io import imread, imshow

# %%
def check_tensor(tensor):
    if isinstance(tensor,list):
        print("Type:",type(tensor))
        print("len:",len(tensor))
    else:
        print("Type:",type(tensor))
        print("Shape:",tensor.shape)
        print("dtype:",tensor.dtype)

def diff_tensor(img1,img2):
    diff = img1-img2
    print("max:",np.max(diff))
    print("minx:",np.min(diff))
    print("mean:",np.mean(abs(diff)))
    print((img1==img2).all())

def show_img(img):
    plt.figure()
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %%
img_path = '/Users/Kenneth_Wang/Personal/Code/Computer_Graphics/homography/data/sample_dog.png'
